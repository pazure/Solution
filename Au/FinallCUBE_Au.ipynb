# %%
import matplotlib
# matplotlib.use('Agg')  
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
from meep.materials import Au


# set plot style
from plot.plot_style import set_plot_style
set_plot_style(colors=False, dpi=300)
# Out:
# Using MPI version 4.1, 1 processes

# %% [markdown]
# # Run simulation

# %%
# Set up material properties.  

permitivity = 14.31# for Au -16.50+1.06j
cube_material = Au
length = 0.3 # um


# Setting up simulation domain
S_x = 4*length
S_y = 4 *length
S_z = 4 * length
cell_size = mp.Vector3(S_x, S_y, S_z)


# Frequency range and ofset Bandwith
cent_wl =  0.7 #0.7
min_wl = 0.65#0.65
max_wl = 0.75#0.75
cent_freq = 1/cent_wl
freq_width = 1/min_wl - 1/max_wl




# define offset of sourc
offset = 0.2

# Define source position
source_postion =  -S_y*0.5  + offset


# Define a gauassian source 
gaussian_pulse = mp.GaussianSource(frequency = cent_freq, 
                                       fwidth = 2*freq_width,
                                        is_integrated = True )


source = [mp.Source(src = gaussian_pulse, 
                    component = mp.Ez, 
                    center = mp.Vector3(0, source_postion),
                    size = mp.Vector3(S_x,0, S_y))]


# set simulation object 
step_size = min([length, min_wl])/20
resolution= 1/step_size
pmls = [mp.PML(thickness = 10*step_size)]


sim = mp.Simulation(resolution= resolution,
                    cell_size= cell_size,
                    sources = source,
                    boundary_layers = pmls,
                    geometry = [],
                    # Courant=0.1
                    )

# Add monitors 
# We are defining wavelenght monitors (DFT monitors)
wls = np.linspace(min_wl,max_wl, 41)
freqs = 1/wls
dft_freqs = [1/min_wl, cent_freq,1/max_wl ]

dft_field = sim.add_dft_fields([mp.Ez],
                              dft_freqs,
                              center = mp.Vector3(),
                             size= mp.Vector3(S_x, S_y) )




# setting up flux monitors 
box_size = length*2

box_mx = sim.add_flux(freqs, mp.FluxRegion(center = mp.Vector3(x = -box_size / 2), size = mp.Vector3(0,box_size,box_size)))
box_px = sim.add_flux(freqs, mp.FluxRegion(center = mp.Vector3(x = box_size / 2), size = mp.Vector3(0,box_size,box_size)))
box_my = sim.add_flux(freqs,mp.FluxRegion(center=mp.Vector3(y=-box_size/2),size=mp.Vector3(x = box_size, z = box_size)))
box_py = sim.add_flux(freqs,mp.FluxRegion(center=mp.Vector3(y=box_size/2),size=mp.Vector3(x = box_size, z = box_size)))
box_mz = sim.add_flux(freqs,mp.FluxRegion(center=mp.Vector3(z=-box_size/2),size=mp.Vector3(x = box_size, y = box_size)))
box_pz = sim.add_flux(freqs,mp.FluxRegion(center=mp.Vector3(z=box_size/2),size=mp.Vector3(x = box_size, y = box_size)))



# visualize the simulation domain
sim.plot2D(output_plane = mp.Volume(center = mp.Vector3(), size = mp.Vector3(S_x,S_y)))
plt.savefig("simXY_empty.png")
plt.show()
plt.close()

sim.plot2D(output_plane = mp.Volume(center = mp.Vector3(), size = mp.Vector3(S_x,0,S_z)))
plt.savefig("simXZ_empty.png")
plt.show()
plt.close()

# %%
sim.run(until_after_sources = mp.stop_when_fields_decayed(10, mp.Ez, mp.Vector3(0,0,box_size/2),1e-4))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0110131 s
# Working in 3D dimensions.
# Computational cell is 1.2 x 1.2 x 1.2 with resolution 66.6667
# time for set_epsilon = 4.16764 s
# -----------
# on time step 1 (time=0.0075), 5.57092 s/step
# on time step 76 (time=0.57), 0.0533343 s/step
# on time step 139 (time=1.0425), 0.0662507 s/step
# on time step 147 (time=1.1025), 0.580069 s/step
# on time step 154 (time=1.155), 0.679663 s/step
# on time step 161 (time=1.2075), 0.71254 s/step
# on time step 166 (time=1.245), 1.43318 s/step
# on time step 175 (time=1.3125), 0.461989 s/step
# on time step 181 (time=1.3575), 0.777291 s/step
# on time step 187 (time=1.4025), 0.791649 s/step
# on time step 218 (time=1.635), 0.148677 s/step
# on time step 287 (time=2.1525), 0.0593319 s/step
# on time step 368 (time=2.76), 0.0495099 s/step
# on time step 419 (time=3.1425), 0.116514 s/step
# on time step 495 (time=3.7125), 0.0532167 s/step
# on time step 563 (time=4.2225), 0.0592413 s/step
# on time step 635 (time=4.7625), 0.0601357 s/step
# on time step 637 (time=4.7775), 3.32523 s/step
# on time step 641 (time=4.8075), 3.43828 s/step
# on time step 716 (time=5.37), 0.0537309 s/step
# on time step 800 (time=6), 0.0477516 s/step
# on time step 840 (time=6.3), 0.129097 s/step
# on time step 843 (time=6.3225), 3.27866 s/step
# on time step 933 (time=6.9975), 0.0444716 s/step
# on time step 1028 (time=7.71), 0.0425392 s/step
# on time step 1052 (time=7.89), 0.231214 s/step
# on time step 1139 (time=8.5425), 0.0463362 s/step
# on time step 1225 (time=9.1875), 0.0465756 s/step
# on time step 1232 (time=9.24), 0.654817 s/step
# on time step 1324 (time=9.93), 0.0436602 s/step
# field decay(t = 10.004999999999999): 0.0675266841500774 / 0.0675266841500774 = 1.0
# on time step 1426 (time=10.695), 0.0396828 s/step
# on time step 1520 (time=11.4), 0.0426479 s/step
# on time step 1603 (time=12.0225), 0.0488911 s/step
# on time step 1667 (time=12.5025), 0.0631962 s/step
# on time step 1765 (time=13.2375), 0.040884 s/step
# on time step 1808 (time=13.56), 0.114389 s/step
# on time step 1810 (time=13.575), 4.29715 s/step
# on time step 1811 (time=13.5825), 4.1646 s/step
# on time step 1860 (time=13.95), 0.0821236 s/step
# on time step 1880 (time=14.1), 0.293665 s/step
# on time step 1882 (time=14.115), 2.77672 s/step
# on time step 1886 (time=14.145), 1.03355 s/step
# on time step 1977 (time=14.8275), 0.0486478 s/step
# on time step 1992 (time=14.94), 0.267574 s/step
# on time step 2067 (time=15.5025), 0.0540534 s/step
# on time step 2161 (time=16.2075), 0.0426275 s/step
# on time step 2219 (time=16.6425), 0.0694836 s/step
# on time step 2323 (time=17.4225), 0.0385533 s/step
# on time step 2381 (time=17.8575), 0.11025 s/step
# on time step 2449 (time=18.3675), 0.0590197 s/step
# on time step 2536 (time=19.02), 0.0462813 s/step
# on time step 2563 (time=19.2225), 0.198602 s/step
# on time step 2565 (time=19.2375), 2.93802 s/step
# on time step 2566 (time=19.245), 4.08523 s/step
# on time step 2606 (time=19.545), 0.123862 s/step
# field decay(t = 20.009999999999998): 0.2501222109628814 / 0.2501222109628814 = 1.0
# on time step 2711 (time=20.3325), 0.0382395 s/step
# on time step 2815 (time=21.1125), 0.0386866 s/step
# on time step 2818 (time=21.135), 1.40791 s/step
# on time step 2821 (time=21.1575), 1.86192 s/step
# on time step 2826 (time=21.195), 0.808272 s/step
# on time step 2829 (time=21.2175), 1.3404 s/step
# on time step 2851 (time=21.3825), 0.207943 s/step
# on time step 2856 (time=21.42), 1.04864 s/step
# on time step 2858 (time=21.435), 2.11846 s/step
# on time step 2907 (time=21.8025), 0.118373 s/step
# on time step 2981 (time=22.3575), 0.0546782 s/step
# on time step 3042 (time=22.815), 0.0664358 s/step
# on time step 3112 (time=23.34), 0.0575232 s/step
# on time step 3145 (time=23.5875), 0.124142 s/step
# on time step 3189 (time=23.9175), 0.0922901 s/step
# on time step 3239 (time=24.2925), 0.0807132 s/step
# on time step 3308 (time=24.81), 0.0584577 s/step
# on time step 3373 (time=25.2975), 0.0630005 s/step
# on time step 3427 (time=25.7025), 0.0746848 s/step
# on time step 3490 (time=26.175), 0.0635998 s/step
# on time step 3560 (time=26.7), 0.0571564 s/step
# on time step 3646 (time=27.345), 0.0466004 s/step
# on time step 3717 (time=27.8775), 0.0571764 s/step
# on time step 3821 (time=28.6575), 0.0385521 s/step
# on time step 3961 (time=29.7075), 0.0285784 s/step
# field decay(t = 30.015): 1.2618883047003556e-05 / 0.2501222109628814 = 5.0450869590610735e-05
# run 0 finished at t = 30.015 (4002 timesteps)

# %%
# Plot DFT monitors
for f in range(len(dft_freqs)):
    Ez_f = sim.get_dft_array(dft_field, mp.Ez, f)
    plt.imshow(np.real(Ez_f), extent = [-S_y/2, S_y/2, -S_x/2, S_x/2])
    plt.savefig(f"Ez_f{1./dft_freqs[f]}.png")

    plt.close()

# %% [markdown]
# # Save empty simulation domain flux data

# %%
box_mx_data_empty = sim.get_flux_data(box_mx)
box_px_data_empty = sim.get_flux_data(box_px)
box_my_data_empty = sim.get_flux_data(box_my)
box_py_data_empty = sim.get_flux_data(box_py)
box_mz_data_empty = sim.get_flux_data(box_mz)
box_pz_data_empty = sim.get_flux_data(box_pz)

# %% [markdown]
# # Incident intensity of incidenting flux.
#  Reveals the frequency components in the incident pulse

# %%
incident_intensity = np.array(mp.get_fluxes(box_my))/(box_size**2)
plt.plot(wls,incident_intensity)
plt.savefig('Inc_Intensity.png')
plt.xlabel("Wavelength($\mu m$)")
plt.ylabel("Amplitude(ar unit)")
plt.show()
plt.close()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_288794/2853090455.py:4: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Wavelength($\mu m$)")

# %%
sim.reset_meep()

# %% [markdown]
# reset  the simulation

# %%
# sphere_refractive_index = 2.0

L = length

cube = mp.Block(
    size=mp.Vector3(L, L, L),    # full lengths in x, y, and z
    center=mp.Vector3(0,0,0),
    material=cube_material
)

geometry = [cube]


# geometry = [mp.Sphere(material= cube_material, center = mp.Vector3(), radius = length)]

# %% [markdown]
# New simulation with material

# %%
# sim = mp.Simulation(resolution= resolution,
#                     cell_size= cell_size,
#                     sources = source,
#                     boundary_layers = pmls,
#                     geometry = geometry,
#                     # Courant=0.1
#                     )

sim = mp.Simulation(resolution = resolution,
                    cell_size = cell_size,
                    sources = source,
                    boundary_layers = pmls,
                    geometry = geometry,
                    Courant = 0.3)
# sim = mp.Simulation(resolution= resolution,
#                     cell_size= cell_size,
#                     sources = source,
#                     boundary_layers = pmls,
#                     geometry = [],
#                     # Courant=0.1
#                     )

# %%
box_size = length*2

dft_field = sim.add_dft_fields([mp.Ez],
                              dft_freqs,
                              center = mp.Vector3(),
                             size= mp.Vector3(S_x, S_y) )

# Adding flux monitors 
box_mx = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(x = -box_size/2),size = mp.Vector3(0, box_size,box_size)))
box_px = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(x = box_size/2),size = mp.Vector3(0, box_size,box_size)))
box_my = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(y =- box_size/2),size = mp.Vector3(x =box_size,z=box_size)))
box_py = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(y = box_size/2),size = mp.Vector3(x =box_size,z=box_size)))
box_mz = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(z =- box_size/2),size = mp.Vector3(x =box_size,y=box_size)))
box_pz = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(z = box_size/2),size = mp.Vector3(x =box_size,y=box_size)))


sim.load_minus_flux_data(box_mx, box_mx_data_empty)
sim.load_minus_flux_data(box_px, box_px_data_empty)
sim.load_minus_flux_data(box_my, box_my_data_empty)
sim.load_minus_flux_data(box_py, box_py_data_empty)
sim.load_minus_flux_data(box_mz, box_mz_data_empty)
sim.load_minus_flux_data(box_pz, box_pz_data_empty)

animate = mp.Animate2D(fields=mp.Ez,
                       realtime=True,
                       output_plane = mp.Volume(center = mp.Vector3(), size = mp.Vector3(S_x, S_y))
)
                    #    field_parameters={'alpha':0.8, 'cmap':'RdBu', 'interpolation':'none'},
                    #    boundary_parameters={'hatch':'o', 'linewidth':1.5, 'facecolor':'y', 'edgecolor':'b', 'alpha':0.3})

# sim.run(mp.at_every(1,animate),until=25)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000856431 s
# Working in 3D dimensions.
# Computational cell is 1.2 x 1.2 x 1.2 with resolution 66.6667
#      block, center = (0,0,0)
#           size (0.3,0.3,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.917629 s
# lorentzian susceptibility: frequency=10.7433, gamma=1.78571
# lorentzian susceptibility: frequency=3.47141, gamma=2.01155
# lorentzian susceptibility: frequency=2.39466, gamma=0.701702
# lorentzian susceptibility: frequency=0.66944, gamma=0.278261
# lorentzian susceptibility: frequency=0.33472, gamma=0.19438
# drude susceptibility: frequency=1e-10, gamma=0.0427474
# -----------

# %%
sim.plot2D(output_plane =mp.Volume(center=mp.Vector3(), size = mp.Vector3(S_x,0,  S_z)))
plt.savefig("simXYwithCube.png")
plt.show()
plt.close()

sim.plot2D(output_plane =mp.Volume(center=mp.Vector3(), size = mp.Vector3(S_x,0,  S_z)))
plt.savefig("simXZwithCube.png")
plt.show()
plt.close()
# Out:
#      block, center = (0,0,0)
#           size (0.3,0.3,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0.3,0.3,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %% [markdown]
# # Run

# %%
sim.run(mp.at_every(0.1,animate),until_after_sources = mp.stop_when_fields_decayed(10, mp.Ez, mp.Vector3(0,0,box_size/2),1e-4))

# save animation
# Out:
# on time step 5 (time=0.0225), 0.806948 s/step
#      block, center = (0,0,0)
#           size (0.3,0.3,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# on time step 31 (time=0.1395), 0.15526 s/step
# on time step 66 (time=0.297), 0.12747 s/step
# on time step 110 (time=0.495), 0.10672 s/step
# on time step 132 (time=0.594), 0.192245 s/step
# on time step 176 (time=0.792), 0.1082 s/step
# on time step 220 (time=0.99), 0.105318 s/step
# on time step 258 (time=1.161), 0.106373 s/step
# on time step 295 (time=1.3275), 0.108735 s/step
# on time step 330 (time=1.485), 0.122986 s/step
# on time step 374 (time=1.683), 0.0951065 s/step
# on time step 401 (time=1.8045), 0.148587 s/step
# on time step 418 (time=1.881), 0.266751 s/step
# on time step 459 (time=2.0655), 0.0988615 s/step
# on time step 484 (time=2.178), 0.193258 s/step
# on time step 528 (time=2.376), 0.124611 s/step
# on time step 572 (time=2.574), 0.124843 s/step
# on time step 595 (time=2.6775), 0.175511 s/step
# on time step 637 (time=2.8665), 0.0954 s/step
# on time step 672 (time=3.024), 0.115251 s/step
# on time step 711 (time=3.1995), 0.103133 s/step
# on time step 748 (time=3.366), 0.114906 s/step
# on time step 792 (time=3.564), 0.103579 s/step
# on time step 836 (time=3.762), 0.106254 s/step
# on time step 880 (time=3.96), 0.103176 s/step
# on time step 924 (time=4.158), 0.115873 s/step
# on time step 968 (time=4.356), 0.099524 s/step
# on time step 1012 (time=4.554), 0.110068 s/step
# on time step 1056 (time=4.752), 0.0957789 s/step
# on time step 1100 (time=4.95), 0.0951528 s/step
# on time step 1144 (time=5.148), 0.0958767 s/step
# on time step 1188 (time=5.346), 0.0971009 s/step
# on time step 1232 (time=5.544), 0.0941933 s/step
# on time step 1276 (time=5.742), 0.0957378 s/step
# on time step 1320 (time=5.94), 0.09918 s/step
# on time step 1364 (time=6.138), 0.0958695 s/step
# on time step 1408 (time=6.336), 0.0933 s/step
# on time step 1452 (time=6.534), 0.0961323 s/step
# on time step 1496 (time=6.732), 0.0987444 s/step
# on time step 1540 (time=6.93), 0.0948823 s/step
# on time step 1584 (time=7.128), 0.0973542 s/step
# on time step 1628 (time=7.326), 0.0946752 s/step
# on time step 1672 (time=7.524), 0.0950482 s/step
# on time step 1716 (time=7.722), 0.0935198 s/step
# on time step 1760 (time=7.92), 0.0947291 s/step
# on time step 1804 (time=8.118), 0.0957015 s/step
# on time step 1848 (time=8.316), 0.0957917 s/step
# on time step 1892 (time=8.514), 0.0953718 s/step
# on time step 1936 (time=8.712), 0.0967908 s/step
# on time step 1980 (time=8.91), 0.0956202 s/step
# on time step 2002 (time=9.009), 0.217891 s/step
# on time step 2024 (time=9.108), 0.195859 s/step
# on time step 2051 (time=9.2295), 0.149638 s/step
# on time step 2090 (time=9.405), 0.204012 s/step
# on time step 2112 (time=9.504), 0.225962 s/step
# on time step 2134 (time=9.603), 0.228981 s/step
# on time step 2156 (time=9.702), 0.471908 s/step
# on time step 2178 (time=9.801), 0.479382 s/step
# on time step 2200 (time=9.9), 0.259603 s/step
# on time step 2222 (time=9.999), 0.2648 s/step
# field decay(t = 10.003499999999999): 0.04068395862117268 / 0.04068395862117268 = 1.0
# on time step 2244 (time=10.098), 0.343172 s/step
# on time step 2266 (time=10.197), 0.266393 s/step
# on time step 2288 (time=10.296), 0.193672 s/step
# on time step 2310 (time=10.395), 0.18505 s/step
# on time step 2337 (time=10.5165), 0.149245 s/step
# on time step 2365 (time=10.6425), 0.144425 s/step
# on time step 2387 (time=10.7415), 0.183315 s/step
# on time step 2419 (time=10.8855), 0.125365 s/step
# on time step 2442 (time=10.989), 0.197138 s/step
# on time step 2486 (time=11.187), 0.115469 s/step
# on time step 2530 (time=11.385), 0.114547 s/step
# on time step 2574 (time=11.583), 0.115265 s/step
# on time step 2618 (time=11.781), 0.114189 s/step
# on time step 2662 (time=11.979), 0.117446 s/step
# on time step 2706 (time=12.177), 0.117655 s/step
# on time step 2750 (time=12.375), 0.126011 s/step
# on time step 2772 (time=12.474), 0.218659 s/step
# on time step 2816 (time=12.672), 0.114149 s/step
# on time step 2860 (time=12.87), 0.108983 s/step
# on time step 2904 (time=13.068), 0.118584 s/step
# on time step 2948 (time=13.266), 0.110859 s/step
# on time step 2992 (time=13.464), 0.117449 s/step
# on time step 3036 (time=13.662), 0.102545 s/step
# on time step 3080 (time=13.86), 0.0958526 s/step
# on time step 3124 (time=14.058), 0.0950135 s/step
# on time step 3168 (time=14.256), 0.0958719 s/step
# on time step 3212 (time=14.454), 0.0949298 s/step
# on time step 3256 (time=14.652), 0.0944481 s/step
# on time step 3300 (time=14.85), 0.102383 s/step
# on time step 3344 (time=15.048), 0.0965913 s/step
# on time step 3388 (time=15.246), 0.0980882 s/step
# on time step 3432 (time=15.444), 0.0969153 s/step
# on time step 3476 (time=15.642), 0.0983691 s/step
# on time step 3520 (time=15.84), 0.0987382 s/step
# on time step 3564 (time=16.038), 0.101145 s/step
# on time step 3608 (time=16.236), 0.0975484 s/step
# on time step 3652 (time=16.434), 0.0954956 s/step
# on time step 3696 (time=16.632), 0.095044 s/step
# on time step 3740 (time=16.83), 0.10213 s/step
# on time step 3784 (time=17.028), 0.0964152 s/step
# on time step 3828 (time=17.226), 0.0953253 s/step
# on time step 3872 (time=17.424), 0.0954049 s/step
# on time step 3916 (time=17.622), 0.0982819 s/step
# on time step 3960 (time=17.82), 0.1092 s/step
# on time step 4004 (time=18.018), 0.0955832 s/step
# on time step 4048 (time=18.216), 0.0958499 s/step
# on time step 4092 (time=18.414), 0.0965209 s/step
# on time step 4136 (time=18.612), 0.097606 s/step
# on time step 4180 (time=18.81), 0.0996149 s/step
# on time step 4224 (time=19.008), 0.110864 s/step
# on time step 4268 (time=19.206), 0.101558 s/step
# on time step 4312 (time=19.404), 0.0955657 s/step
# on time step 4356 (time=19.602), 0.0971561 s/step
# on time step 4400 (time=19.8), 0.096277 s/step
# on time step 4444 (time=19.998), 0.0955853 s/step
# field decay(t = 20.006999999999998): 0.1340863689162605 / 0.1340863689162605 = 1.0
# on time step 4488 (time=20.196), 0.0959106 s/step
# on time step 4532 (time=20.394), 0.100675 s/step
# on time step 4576 (time=20.592), 0.0954967 s/step
# on time step 4620 (time=20.79), 0.0959658 s/step
# on time step 4664 (time=20.988), 0.0955826 s/step
# on time step 4708 (time=21.186), 0.0964061 s/step
# on time step 4752 (time=21.384), 0.0974871 s/step
# on time step 4796 (time=21.582), 0.0954301 s/step
# on time step 4840 (time=21.78), 0.0949318 s/step
# on time step 4884 (time=21.978), 0.0979844 s/step
# on time step 4928 (time=22.176), 0.0950472 s/step
# on time step 4968 (time=22.356), 0.100657 s/step
# on time step 5000 (time=22.5), 0.125721 s/step
# on time step 5040 (time=22.68), 0.100831 s/step
# on time step 5082 (time=22.869), 0.0971861 s/step
# on time step 5126 (time=23.067), 0.0955626 s/step
# on time step 5170 (time=23.265), 0.0969901 s/step
# on time step 5214 (time=23.463), 0.0956108 s/step
# on time step 5258 (time=23.661), 0.0948644 s/step
# on time step 5302 (time=23.859), 0.0954863 s/step
# on time step 5346 (time=24.057), 0.0962477 s/step
# on time step 5390 (time=24.255), 0.0947387 s/step
# on time step 5434 (time=24.453), 0.0951226 s/step
# on time step 5478 (time=24.651), 0.095905 s/step
# on time step 5522 (time=24.849), 0.0954709 s/step
# on time step 5566 (time=25.047), 0.0962186 s/step
# on time step 5610 (time=25.245), 0.0949659 s/step
# on time step 5654 (time=25.443), 0.0944547 s/step
# on time step 5698 (time=25.641), 0.0975046 s/step
# on time step 5742 (time=25.839), 0.101236 s/step
# on time step 5786 (time=26.037), 0.110624 s/step
# on time step 5830 (time=26.235), 0.0991216 s/step
# on time step 5874 (time=26.433), 0.0965763 s/step
# on time step 5918 (time=26.631), 0.0995654 s/step
# on time step 5962 (time=26.829), 0.0994522 s/step
# on time step 6006 (time=27.027), 0.0966222 s/step
# on time step 6050 (time=27.225), 0.0971787 s/step
# on time step 6094 (time=27.423), 0.0983061 s/step
# on time step 6138 (time=27.621), 0.0987792 s/step
# on time step 6182 (time=27.819), 0.0967433 s/step
# on time step 6226 (time=28.017), 0.100692 s/step
# on time step 6270 (time=28.215), 0.099339 s/step
# on time step 6314 (time=28.413), 0.0988144 s/step
# on time step 6358 (time=28.611), 0.0984169 s/step
# on time step 6402 (time=28.809), 0.0992067 s/step
# on time step 6446 (time=29.007), 0.0999679 s/step
# on time step 6490 (time=29.205), 0.100755 s/step
# on time step 6534 (time=29.403), 0.100229 s/step
# on time step 6578 (time=29.601), 0.0995687 s/step
# on time step 6622 (time=29.799), 0.0995459 s/step
# on time step 6666 (time=29.997), 0.098045 s/step
# field decay(t = 30.010499999999997): 5.207579233265183e-06 / 0.1340863689162605 = 3.8837499108633594e-05
# run 0 finished at t = 30.010499999999997 (6669 timesteps)

# %%
animate.to_mp4(fps=10, filename="animation.mp4")
# Out:
# Generating MP4...

# %%
box_mx_flux = np.array(mp.get_fluxes(box_mx))
box_px_flux = np.array(mp.get_fluxes(box_px))
box_my_flux = np.array(mp.get_fluxes(box_my))
box_py_flux = np.array(mp.get_fluxes(box_py))
box_mz_flux = np.array(mp.get_fluxes(box_mz))
box_pz_flux = np.array(mp.get_fluxes(box_pz))

total_flux = -box_mx_flux + box_px_flux -box_my_flux+ box_py_flux  -box_mz_flux+ box_pz_flux
crossection = total_flux/incident_intensity



plt.figure()
plt.plot(wls, crossection/ (length**2), "-", color = 'red', label = ("Total crossection"))
plt.xlabel("Wavelength($\mu m$)")
plt.ylabel("$\sigma$_{$\mu m^2$}")
plt.title("Scattering Eficiency")
plt.legend()
plt.savefig("Scattering_spectrum.png")
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_288794/3295812429.py:15: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Wavelength($\mu m$)")
# /tmp/ipykernel_288794/3295812429.py:16: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel("$\sigma$_{$\mu m^2$}")

# %%
L = length

plt.figure()
# plt.plot(wls, crossection/ (L**2), "x", color = 'red', label = ("Total crossection"))
plt.plot(wls, box_mx_flux/ (L**2),  label = ("-x"))
plt.plot(wls, box_px_flux/ (L**2), label = ("+x"))
plt.plot(wls, box_my_flux/ (L**2),  label = ("-y"))
plt.plot(wls, box_py_flux/ (L**2),   label = ("+y"))
plt.plot(wls, box_mz_flux/ (L**2),  label = ("-z"))
plt.plot(wls, box_pz_flux/ (L**2),  label = ("+z"))
plt.xlabel("Wavelength(nm)")
plt.ylabel("Scattering efficiency(arbitrary units)")
plt.legend()
plt.title('Directional Decomposition of Scattered field')
plt.savefig("Scattering_directional_decomposition.png")
plt.show()

# %%
print("Au valid freq range:", Au.valid_freq_range)
# Out:
# Au valid freq range: FreqRange(min=0.16131113692089302, max=4.0327458966810505)

# %%
# sim.plot3D()              # this will draw into the Agg canvas
# plt.savefig("3Dfield.png", dpi=150)

# %%
# import numpy as np
# import scipy.special as sp
# import scipy.interpolate as interp
# import matplotlib.pyplot as plt
# import scipy.optimize as op
# import matplotlib

# matplotlib.rcParams.update({'font.size': 15})

# HBAR = 1.0545718E-34
# ME = 9.10938356E-31
# E0 = 1.60217662E-19
# NE = 5.541318196761572e28
# NE = 5.476415562682574e28

# mu0 = 1.2566370614E-06;
# ep0 = 8.85418781762E-12;
# h = 4.135667516000000e-15;
# c = 3e8;


# def x_Bessel_prime(n, x, j):
#     xj_prime = x * j[:, 1] - n * j[:, 0];
#     return xj_prime;

# def Mie_Solver(Sphere_Radius, Sphere_refractive_index, Wavelengths, RefractiveIndex_Outside = 1, max_iter = 20):
#     c = 3e8;
#     N_m = RefractiveIndex_Outside;  # vacuum
#     Lambda = Wavelengths
#     Freq = c / Lambda;
#     omega = 2 * np.pi * Freq;

#     k = 2 * np.pi * N_m / Lambda;
#     x = Sphere_Radius * k;

#     if hasattr(Sphere_refractive_index, "__len__"):
#         N_s = Sphere_refractive_index
#     else:
#         N_s = Wavelengths / Wavelengths * Sphere_refractive_index

#     N = N_s / N_m;

#     j_mx = np.zeros([len(omega), 3], dtype='complex128');
#     j_x = np.zeros([len(omega), 3], dtype='complex128');
#     y_x = np.zeros([len(omega), 3], dtype='complex128');
#     xjx_prime = np.zeros([len(omega), 3], dtype='complex128');
#     NxjNx_prime = np.zeros([len(omega), 3], dtype='complex128');
#     h_x = np.zeros([len(omega), 3], dtype='complex128');
#     xhx_prime = np.zeros([len(omega), 3], dtype='complex128');

#     I = 1j

#     i = 0;
#     j_x[:, 0] = sp.jn(i + 0.5, x) * np.sqrt(np.pi / (2 * x))
#     j_mx[:, 0] = sp.jn(i + 0.5, N * x) * np.sqrt(np.pi / (2 * N * x))
#     y_x[:, 0] = sp.yv(i + 0.5, x) * np.sqrt(np.pi / (2 * x))
#     h_x[:, 0] = j_x[:, 0] + I * y_x[:, 0];

#     Q_sca = 0;
#     Q_ext = 0;

#     A_n_track = []
#     B_n_track = []

#     for i in range(1, max_iter + 1):
#         # print(i)

#         j_x[:, 2] = j_x[:, 1];
#         j_x[:, 1] = j_x[:, 0];

#         j_mx[:, 2] = j_mx[:, 1];
#         j_mx[:, 1] = j_mx[:, 0];

#         y_x[:, 2] = y_x[:, 1];
#         y_x[:, 1] = y_x[:, 0];

#         j_x[:, 0] = sp.jv(i + 0.5, x) * np.sqrt(np.pi / (2 * x))
#         j_mx[:, 0] = sp.jv(i + 0.5, N * x) * np.sqrt(np.pi / (2 * N * x))
#         y_x[:, 0] = sp.yv(i + 0.5, x) * np.sqrt(np.pi / (2 * x))

#         h_x[:, 2] = h_x[:, 1];
#         h_x[:, 1] = h_x[:, 0];
#         h_x[:, 0] = j_x[:, 0] + I * y_x[:, 0];

#         xjx_prime[:, 0] = x_Bessel_prime(i, x, j_x);
#         NxjNx_prime[:, 0] = x_Bessel_prime(i, N * x, j_mx);
#         xhx_prime[:, 0] = x_Bessel_prime(i, x, h_x);

#         A_n = N * N * j_mx[:, 0] * xjx_prime[:, 0] - j_x[:, 0] * NxjNx_prime[:, 0];
#         A_n = - A_n / (N * N * j_mx[:, 0] * xhx_prime[:, 0] - h_x[:, 0] * NxjNx_prime[:, 0]);

#         B_n = j_mx[:, 0] * xjx_prime[:, 0] - j_x[:, 0] * NxjNx_prime[:, 0];
#         B_n = - B_n / (j_mx[:, 0] * xhx_prime[:, 0] - h_x[:, 0] * NxjNx_prime[:, 0]);

#         A_n_track.append(A_n)
#         B_n_track.append(B_n)

#         Q_sca = Q_sca + (2 * i + 1) * (np.abs(A_n) * np.abs(A_n) + np.abs(B_n) * np.abs(B_n));
#         Q_ext = Q_ext + (2 * i + 1) * (np.real(A_n + B_n));

#     Q_sca = Q_sca * 2 / (x * x);
#     Q_ext = -Q_ext * 2 / (x * x);
#     Q_abs = Q_ext - Q_sca;

#     return Q_sca, Q_abs, Q_ext
