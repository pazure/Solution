# %%
import matplotlib
# matplotlib.use('Agg')  
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
from meep.materials import Si


# set plot style
from plot.plot_style import set_plot_style
set_plot_style(colors=False, dpi=300)
# Out:
# Using MPI version 4.1, 1 processes

# %% [markdown]
# # Run simulation

# %%
# Set up material properties.  

permitivity = 14.31# for Au -16.50+1.06j
cube_material = Si
length = 0.3 # um


# Setting up simulation domain
S_x = 4*length
S_y = 4 *length
S_z = 4 * length
cell_size = mp.Vector3(S_x, S_y, S_z)


# Frequency range and ofset Bandwith
cent_wl =  0.7 #0.7
min_wl = 0.65#0.65
max_wl = 0.75#0.75
cent_freq = 1/cent_wl
freq_width = 1/min_wl - 1/max_wl




# define offset of sourc
offset = 0.2

# Define source position
source_postion =  -S_y*0.5  + offset


# Define a gauassian source 
gaussian_pulse = mp.GaussianSource(frequency = cent_freq, 
                                       fwidth = 2*freq_width,
                                        is_integrated = True )


source = [mp.Source(src = gaussian_pulse, 
                    component = mp.Ez, 
                    center = mp.Vector3(0, source_postion),
                    size = mp.Vector3(S_x,0, S_y))]


# set simulation object 
step_size = min([length, min_wl])/20
resolution= 1/step_size
pmls = [mp.PML(thickness = 10*step_size)]


sim = mp.Simulation(resolution= resolution,
                    cell_size= cell_size,
                    sources = source,
                    boundary_layers = pmls,
                    geometry = [],
                    # Courant=0.1
                    )

# Add monitors 
# We are defining wavelenght monitors (DFT monitors)
wls = np.linspace(min_wl,max_wl, 41)
freqs = 1/wls
dft_freqs = [1/min_wl, cent_freq,1/max_wl ]

dft_field = sim.add_dft_fields([mp.Ez],
                              dft_freqs,
                              center = mp.Vector3(),
                             size= mp.Vector3(S_x, S_y) )




# setting up flux monitors 
box_size = length*2

box_mx = sim.add_flux(freqs, mp.FluxRegion(center = mp.Vector3(x = -box_size / 2), size = mp.Vector3(0,box_size,box_size)))
box_px = sim.add_flux(freqs, mp.FluxRegion(center = mp.Vector3(x = box_size / 2), size = mp.Vector3(0,box_size,box_size)))
box_my = sim.add_flux(freqs,mp.FluxRegion(center=mp.Vector3(y=-box_size/2),size=mp.Vector3(x = box_size, z = box_size)))
box_py = sim.add_flux(freqs,mp.FluxRegion(center=mp.Vector3(y=box_size/2),size=mp.Vector3(x = box_size, z = box_size)))
box_mz = sim.add_flux(freqs,mp.FluxRegion(center=mp.Vector3(z=-box_size/2),size=mp.Vector3(x = box_size, y = box_size)))
box_pz = sim.add_flux(freqs,mp.FluxRegion(center=mp.Vector3(z=box_size/2),size=mp.Vector3(x = box_size, y = box_size)))



# visualize the simulation domain
sim.plot2D(output_plane = mp.Volume(center = mp.Vector3(), size = mp.Vector3(S_x,S_y)))
plt.savefig("simXY_empty.png")
plt.show()
plt.close()

sim.plot2D(output_plane = mp.Volume(center = mp.Vector3(), size = mp.Vector3(S_x,0,S_z)))
plt.savefig("simXZ_empty.png")
plt.show()
plt.close()

# %%
sim.run(until_after_sources = mp.stop_when_fields_decayed(10, mp.Ez, mp.Vector3(0,0,box_size/2),1e-4))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000451424 s
# Working in 3D dimensions.
# Computational cell is 1.2 x 1.2 x 1.2 with resolution 66.6667
# time for set_epsilon = 0.612497 s
# -----------
# on time step 209 (time=1.5675), 0.019154 s/step
# on time step 446 (time=3.345), 0.0169394 s/step
# on time step 608 (time=4.56), 0.0247035 s/step
# on time step 821 (time=6.1575), 0.0188222 s/step
# on time step 1041 (time=7.8075), 0.0182119 s/step
# on time step 1266 (time=9.495), 0.0177897 s/step
# field decay(t = 10.004999999999999): 0.0675266841500774 / 0.0675266841500774 = 1.0
# on time step 1493 (time=11.1975), 0.0176664 s/step
# on time step 1731 (time=12.9825), 0.0168627 s/step
# on time step 1940 (time=14.55), 0.0192054 s/step
# on time step 2173 (time=16.2975), 0.017197 s/step
# on time step 2455 (time=18.4125), 0.0141963 s/step
# field decay(t = 20.009999999999998): 0.2501222109628814 / 0.2501222109628814 = 1.0
# on time step 2683 (time=20.1225), 0.0175664 s/step
# on time step 2929 (time=21.9675), 0.0163011 s/step
# on time step 3164 (time=23.73), 0.0170736 s/step
# on time step 3280 (time=24.6), 0.034515 s/step
# on time step 3419 (time=25.6425), 0.0288301 s/step
# on time step 3654 (time=27.405), 0.0170498 s/step
# on time step 3921 (time=29.4075), 0.0149898 s/step
# field decay(t = 30.015): 1.2618883047003556e-05 / 0.2501222109628814 = 5.0450869590610735e-05
# run 0 finished at t = 30.015 (4002 timesteps)

# %%
# Plot DFT monitors
for f in range(len(dft_freqs)):
    Ez_f = sim.get_dft_array(dft_field, mp.Ez, f)
    plt.imshow(np.real(Ez_f), extent = [-S_y/2, S_y/2, -S_x/2, S_x/2])
    plt.savefig(f"Ez_f{1./dft_freqs[f]}.png")

    plt.close()

# %% [markdown]
# # Save empty simulation domain flux data

# %%
box_mx_data_empty = sim.get_flux_data(box_mx)
box_px_data_empty = sim.get_flux_data(box_px)
box_my_data_empty = sim.get_flux_data(box_my)
box_py_data_empty = sim.get_flux_data(box_py)
box_mz_data_empty = sim.get_flux_data(box_mz)
box_pz_data_empty = sim.get_flux_data(box_pz)

# %% [markdown]
# # Incident intensity of incidenting flux.
#  Reveals the frequency components in the incident pulse

# %%
incident_intensity = np.array(mp.get_fluxes(box_my))/(box_size**2)
plt.plot(wls,incident_intensity)
plt.savefig('Inc_Intensity.png')
plt.xlabel("Wavelength($\mu m$)")
plt.ylabel("Amplitude(ar unit)")
plt.show()
plt.close()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_299208/2853090455.py:4: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Wavelength($\mu m$)")

# %%
sim.reset_meep()

# %% [markdown]
# reset  the simulation

# %%
# sphere_refractive_index = 2.0

L = length

cube = mp.Block(
    size=mp.Vector3(L, L, L),    # full lengths in x, y, and z
    center=mp.Vector3(0,0,0),
    material=cube_material
)

geometry = [cube]


# geometry = [mp.Sphere(material= cube_material, center = mp.Vector3(), radius = length)]

# %% [markdown]
# New simulation with material

# %%
# sim = mp.Simulation(resolution= resolution,
#                     cell_size= cell_size,
#                     sources = source,
#                     boundary_layers = pmls,
#                     geometry = geometry,
#                     # Courant=0.1
#                     )

sim = mp.Simulation(resolution = resolution,
                    cell_size = cell_size,
                    sources = source,
                    boundary_layers = pmls,
                    geometry = geometry,
                    Courant = 0.3)
# sim = mp.Simulation(resolution= resolution,
#                     cell_size= cell_size,
#                     sources = source,
#                     boundary_layers = pmls,
#                     geometry = [],
#                     # Courant=0.1
#                     )

# %%
box_size = length*2

dft_field = sim.add_dft_fields([mp.Ez],
                              dft_freqs,
                              center = mp.Vector3(),
                             size= mp.Vector3(S_x, S_y) )

# Adding flux monitors 
box_mx = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(x = -box_size/2),size = mp.Vector3(0, box_size,box_size)))
box_px = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(x = box_size/2),size = mp.Vector3(0, box_size,box_size)))
box_my = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(y =- box_size/2),size = mp.Vector3(x =box_size,z=box_size)))
box_py = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(y = box_size/2),size = mp.Vector3(x =box_size,z=box_size)))
box_mz = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(z =- box_size/2),size = mp.Vector3(x =box_size,y=box_size)))
box_pz = sim.add_flux(freqs, mp.FluxRegion(center= mp.Vector3(z = box_size/2),size = mp.Vector3(x =box_size,y=box_size)))


sim.load_minus_flux_data(box_mx, box_mx_data_empty)
sim.load_minus_flux_data(box_px, box_px_data_empty)
sim.load_minus_flux_data(box_my, box_my_data_empty)
sim.load_minus_flux_data(box_py, box_py_data_empty)
sim.load_minus_flux_data(box_mz, box_mz_data_empty)
sim.load_minus_flux_data(box_pz, box_pz_data_empty)

animate = mp.Animate2D(fields=mp.Ez,
                       realtime=True,
                       output_plane = mp.Volume(center = mp.Vector3(), size = mp.Vector3(S_x, S_y))
)
                    #    field_parameters={'alpha':0.8, 'cmap':'RdBu', 'interpolation':'none'},
                    #    boundary_parameters={'hatch':'o', 'linewidth':1.5, 'facecolor':'y', 'edgecolor':'b', 'alpha':0.3})

# sim.run(mp.at_every(1,animate),until=25)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00100068 s
# Working in 3D dimensions.
# Computational cell is 1.2 x 1.2 x 1.2 with resolution 66.6667
#      block, center = (0,0,0)
#           size (0.3,0.3,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.900791 s
# lorentzian susceptibility: frequency=0.000905797, gamma=0
# lorentzian susceptibility: frequency=0.88125, gamma=0
# lorentzian susceptibility: frequency=3.31657, gamma=0
# -----------

# %%
sim.plot2D(output_plane =mp.Volume(center=mp.Vector3(), size = mp.Vector3(S_x,0,  S_z)))
plt.savefig("simXYwithCube.png")
plt.show()
plt.close()

sim.plot2D(output_plane =mp.Volume(center=mp.Vector3(), size = mp.Vector3(S_x,0,  S_z)))
plt.savefig("simXZwithCube.png")
plt.show()
plt.close()
# Out:
#      block, center = (0,0,0)
#           size (0.3,0.3,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0.3,0.3,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %% [markdown]
# # Run

# %%
sim.run(mp.at_every(0.1,animate),until_after_sources = mp.stop_when_fields_decayed(10, mp.Ez, mp.Vector3(0,0,box_size/2),1e-4))

# save animation
# Out:
# /home/pazure/miniconda3/envs/pmp/lib/python3.13/site-packages/meep/simulation.py:1660: RuntimeWarning: Note: your sources include frequencies outside the range of validity of the material models. This is fine as long as you eventually only look at outputs (fluxes, resonant modes, etc.) at valid frequencies.
#   warnings.warn(warn_src, RuntimeWarning)
# /home/pazure/miniconda3/envs/pmp/lib/python3.13/site-packages/meep/simulation.py:1664: RuntimeWarning: DFT frequency 1.5384615384615383 is out of material's range of 0.09090909090909091-0.7352941176470588
#   warnings.warn(
# /home/pazure/miniconda3/envs/pmp/lib/python3.13/site-packages/meep/simulation.py:1664: RuntimeWarning: DFT frequency 1.3333333333333333 is out of material's range of 0.09090909090909091-0.7352941176470588
#   warnings.warn(
#      block, center = (0,0,0)
#           size (0.3,0.3,0.3)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# on time step 25 (time=0.1125), 0.160908 s/step
# on time step 88 (time=0.396), 0.0753993 s/step
# on time step 153 (time=0.6885), 0.0616818 s/step
# on time step 198 (time=0.891), 0.100756 s/step
# on time step 248 (time=1.116), 0.0802844 s/step
# on time step 299 (time=1.3455), 0.0787089 s/step
# on time step 352 (time=1.584), 0.0886679 s/step
# on time step 404 (time=1.818), 0.0770123 s/step
# on time step 462 (time=2.079), 0.0898456 s/step
# on time step 528 (time=2.376), 0.0762113 s/step
# on time step 589 (time=2.6505), 0.065813 s/step
# on time step 638 (time=2.871), 0.108114 s/step
# on time step 697 (time=3.1365), 0.0679073 s/step
# on time step 748 (time=3.366), 0.0909337 s/step
# on time step 814 (time=3.663), 0.0742093 s/step
# on time step 880 (time=3.96), 0.0764048 s/step
# on time step 936 (time=4.212), 0.0715365 s/step
# on time step 990 (time=4.455), 0.0864534 s/step
# on time step 1056 (time=4.752), 0.0738787 s/step
# on time step 1122 (time=5.049), 0.0761689 s/step
# on time step 1186 (time=5.337), 0.0625779 s/step
# on time step 1232 (time=5.544), 0.109003 s/step
# on time step 1298 (time=5.841), 0.0744398 s/step
# on time step 1364 (time=6.138), 0.0723785 s/step
# on time step 1408 (time=6.336), 0.0927169 s/step
# on time step 1462 (time=6.579), 0.0741466 s/step
# on time step 1518 (time=6.831), 0.0806482 s/step
# on time step 1584 (time=7.128), 0.0728608 s/step
# on time step 1649 (time=7.4205), 0.0617149 s/step
# on time step 1694 (time=7.623), 0.110804 s/step
# on time step 1750 (time=7.875), 0.0714598 s/step
# on time step 1804 (time=8.118), 0.0997311 s/step
# on time step 1861 (time=8.3745), 0.0705295 s/step
# on time step 1914 (time=8.613), 0.0915888 s/step
# on time step 1980 (time=8.91), 0.0757804 s/step
# on time step 2044 (time=9.198), 0.0625207 s/step
# on time step 2090 (time=9.405), 0.0965785 s/step
# on time step 2156 (time=9.702), 0.0759243 s/step
# on time step 2222 (time=9.999), 0.0759064 s/step
# field decay(t = 10.003499999999999): 0.046024951869753465 / 0.046024951869753465 = 1.0
# on time step 2274 (time=10.233), 0.0769561 s/step
# on time step 2332 (time=10.494), 0.0806131 s/step
# on time step 2395 (time=10.7775), 0.0635188 s/step
# on time step 2442 (time=10.989), 0.0999619 s/step
# on time step 2496 (time=11.232), 0.0743024 s/step
# on time step 2552 (time=11.484), 0.0876125 s/step
# on time step 2618 (time=11.781), 0.0733135 s/step
# on time step 2684 (time=12.078), 0.0738508 s/step
# on time step 2750 (time=12.375), 0.0772971 s/step
# on time step 2811 (time=12.6495), 0.0657795 s/step
# on time step 2860 (time=12.87), 0.0960075 s/step
# on time step 2926 (time=13.167), 0.0724107 s/step
# on time step 2992 (time=13.464), 0.0755372 s/step
# on time step 3050 (time=13.725), 0.0695199 s/step
# on time step 3102 (time=13.959), 0.093764 s/step
# on time step 3158 (time=14.211), 0.0716292 s/step
# on time step 3204 (time=14.418), 0.0870775 s/step
# on time step 3256 (time=14.652), 0.0920655 s/step
# on time step 3319 (time=14.9355), 0.0638689 s/step
# on time step 3360 (time=15.12), 0.0978261 s/step
# on time step 3400 (time=15.3), 0.100781 s/step
# on time step 3432 (time=15.444), 0.142382 s/step
# on time step 3477 (time=15.6465), 0.0893371 s/step
# on time step 3520 (time=15.84), 0.0998966 s/step
# on time step 3570 (time=16.065), 0.0802967 s/step
# on time step 3630 (time=16.335), 0.0907273 s/step
# on time step 3696 (time=16.632), 0.0703245 s/step
# on time step 3762 (time=16.929), 0.076225 s/step
# on time step 3828 (time=17.226), 0.0741106 s/step
# on time step 3894 (time=17.523), 0.0699198 s/step
# on time step 3960 (time=17.82), 0.0713762 s/step
# on time step 4026 (time=18.117), 0.0730958 s/step
# on time step 4092 (time=18.414), 0.0762543 s/step
# on time step 4158 (time=18.711), 0.0711401 s/step
# on time step 4224 (time=19.008), 0.069468 s/step
# on time step 4290 (time=19.305), 0.0702785 s/step
# on time step 4356 (time=19.602), 0.0716451 s/step
# on time step 4422 (time=19.899), 0.0725707 s/step
# field decay(t = 20.006999999999998): 0.15346193400568553 / 0.15346193400568553 = 1.0
# on time step 4488 (time=20.196), 0.0749373 s/step
# on time step 4552 (time=20.484), 0.0627399 s/step
# on time step 4598 (time=20.691), 0.0985376 s/step
# on time step 4664 (time=20.988), 0.0746889 s/step
# on time step 4730 (time=21.285), 0.0752507 s/step
# on time step 4796 (time=21.582), 0.0767187 s/step
# on time step 4842 (time=21.789), 0.0875342 s/step
# on time step 4900 (time=22.05), 0.0694107 s/step
# on time step 4950 (time=22.275), 0.09804 s/step
# on time step 5016 (time=22.572), 0.0794107 s/step
# on time step 5079 (time=22.8555), 0.0635327 s/step
# on time step 5125 (time=23.0625), 0.0871189 s/step
# on time step 5170 (time=23.265), 0.111409 s/step
# on time step 5235 (time=23.5575), 0.0615779 s/step
# on time step 5280 (time=23.76), 0.103732 s/step
# on time step 5346 (time=24.057), 0.0794236 s/step
# on time step 5412 (time=24.354), 0.0781389 s/step
# on time step 5477 (time=24.6465), 0.0618278 s/step
# on time step 5522 (time=24.849), 0.104639 s/step
# on time step 5587 (time=25.1415), 0.0615652 s/step
# on time step 5632 (time=25.344), 0.106916 s/step
# on time step 5698 (time=25.641), 0.0789979 s/step
# on time step 5759 (time=25.9155), 0.065969 s/step
# on time step 5808 (time=26.136), 0.0960058 s/step
# on time step 5871 (time=26.4195), 0.0636881 s/step
# on time step 5918 (time=26.631), 0.100488 s/step
# on time step 5982 (time=26.919), 0.0625207 s/step
# on time step 6028 (time=27.126), 0.101044 s/step
# on time step 6094 (time=27.423), 0.0783373 s/step
# on time step 6160 (time=27.72), 0.0782816 s/step
# on time step 6225 (time=28.0125), 0.0617706 s/step
# on time step 6270 (time=28.215), 0.107448 s/step
# on time step 6336 (time=28.512), 0.0775789 s/step
# on time step 6380 (time=28.71), 0.0936105 s/step
# on time step 6442 (time=28.989), 0.0646389 s/step
# on time step 6490 (time=29.205), 0.101018 s/step
# on time step 6552 (time=29.484), 0.0646454 s/step
# on time step 6600 (time=29.7), 0.100706 s/step
# on time step 6664 (time=29.988), 0.062555 s/step
# field decay(t = 30.010499999999997): 0.007262990465045638 / 0.15346193400568553 = 0.0473276354302726
# on time step 6710 (time=30.195), 0.101602 s/step
# on time step 6774 (time=30.483), 0.0627636 s/step
# on time step 6820 (time=30.69), 0.101269 s/step
# on time step 6886 (time=30.987), 0.0796045 s/step
# on time step 6952 (time=31.284), 0.0774727 s/step
# on time step 7014 (time=31.563), 0.0648864 s/step
# on time step 7062 (time=31.779), 0.0967667 s/step
# on time step 7126 (time=32.067), 0.0628656 s/step
# on time step 7172 (time=32.274), 0.113843 s/step
# on time step 7238 (time=32.571), 0.0791926 s/step
# on time step 7304 (time=32.868), 0.0763989 s/step
# on time step 7357 (time=33.1065), 0.0755538 s/step
# on time step 7414 (time=33.363), 0.0888332 s/step
# on time step 7478 (time=33.651), 0.0628828 s/step
# on time step 7524 (time=33.858), 0.10502 s/step
# on time step 7590 (time=34.155), 0.0784317 s/step
# on time step 7656 (time=34.452), 0.0780797 s/step
# on time step 7722 (time=34.749), 0.0788531 s/step
# on time step 7782 (time=35.019), 0.0669166 s/step
# on time step 7828 (time=35.226), 0.0870546 s/step
# on time step 7876 (time=35.442), 0.0984695 s/step
# on time step 7934 (time=35.703), 0.06909 s/step
# on time step 7986 (time=35.937), 0.0960318 s/step
# on time step 8049 (time=36.2205), 0.0636606 s/step
# on time step 8096 (time=36.432), 0.100547 s/step
# on time step 8159 (time=36.7155), 0.0635636 s/step
# on time step 8206 (time=36.927), 0.101676 s/step
# on time step 8272 (time=37.224), 0.0785072 s/step
# on time step 8335 (time=37.5075), 0.063845 s/step
# on time step 8382 (time=37.719), 0.105654 s/step
# on time step 8448 (time=38.016), 0.0780927 s/step
# on time step 8511 (time=38.2995), 0.0635982 s/step
# on time step 8558 (time=38.511), 0.0996819 s/step
# on time step 8613 (time=38.7585), 0.0731733 s/step
# on time step 8662 (time=38.979), 0.081822 s/step
# on time step 8712 (time=39.204), 0.0977958 s/step
# on time step 8773 (time=39.4785), 0.0658541 s/step
# on time step 8822 (time=39.699), 0.0981037 s/step
# on time step 8888 (time=39.996), 0.0787464 s/step
# field decay(t = 40.013999999999996): 0.0060652376483108505 / 0.15346193400568553 = 0.039522749974506007
# on time step 8953 (time=40.2885), 0.0617038 s/step
# on time step 8998 (time=40.491), 0.103601 s/step
# on time step 9060 (time=40.77), 0.0647464 s/step
# on time step 9108 (time=40.986), 0.100689 s/step
# on time step 9174 (time=41.283), 0.0778964 s/step
# on time step 9240 (time=41.58), 0.078215 s/step
# on time step 9305 (time=41.8725), 0.0617992 s/step
# on time step 9350 (time=42.075), 0.104349 s/step
# on time step 9411 (time=42.3495), 0.0656591 s/step
# on time step 9460 (time=42.57), 0.0965668 s/step
# on time step 9525 (time=42.8625), 0.0618855 s/step
# on time step 9570 (time=43.065), 0.111085 s/step
# on time step 9633 (time=43.3485), 0.0635403 s/step
# on time step 9680 (time=43.56), 0.099656 s/step
# on time step 9745 (time=43.8525), 0.0618306 s/step
# on time step 9790 (time=44.055), 0.10344 s/step
# on time step 9856 (time=44.352), 0.0788463 s/step
# on time step 9920 (time=44.64), 0.0628627 s/step
# on time step 9966 (time=44.847), 0.106333 s/step
# on time step 10024 (time=45.108), 0.0690138 s/step
# on time step 10076 (time=45.342), 0.0924875 s/step
# on time step 10140 (time=45.63), 0.0627519 s/step
# on time step 10186 (time=45.837), 0.102204 s/step
# on time step 10252 (time=46.134), 0.0798352 s/step
# on time step 10313 (time=46.4085), 0.0656601 s/step
# on time step 10362 (time=46.629), 0.0995156 s/step
# on time step 10424 (time=46.908), 0.0647526 s/step
# on time step 10472 (time=47.124), 0.0985897 s/step
# on time step 10536 (time=47.412), 0.0628321 s/step
# on time step 10582 (time=47.619), 0.102554 s/step
# on time step 10648 (time=47.916), 0.0774387 s/step
# on time step 10714 (time=48.213), 0.0788853 s/step
# on time step 10780 (time=48.51), 0.0784264 s/step
# on time step 10846 (time=48.807), 0.0788967 s/step
# on time step 10890 (time=49.005), 0.10564 s/step
# on time step 10942 (time=49.239), 0.0771503 s/step
# on time step 10980 (time=49.41), 0.105734 s/step
# on time step 11043 (time=49.6935), 0.06379 s/step
# on time step 11088 (time=49.896), 0.107473 s/step
# field decay(t = 50.0175): 0.0015563655118974913 / 0.15346193400568553 = 0.010141704012669554
# on time step 11142 (time=50.139), 0.074489 s/step
# on time step 11195 (time=50.3775), 0.0756247 s/step
# on time step 11242 (time=50.589), 0.100726 s/step
# on time step 11308 (time=50.886), 0.0796487 s/step
# on time step 11372 (time=51.174), 0.0628603 s/step
# on time step 11418 (time=51.381), 0.101102 s/step
# on time step 11484 (time=51.678), 0.0782943 s/step
# on time step 11549 (time=51.9705), 0.0616669 s/step
# on time step 11594 (time=52.173), 0.10475 s/step
# on time step 11656 (time=52.452), 0.0649086 s/step
# on time step 11704 (time=52.668), 0.101261 s/step
# on time step 11760 (time=52.92), 0.0717672 s/step
# on time step 11814 (time=53.163), 0.0891626 s/step
# on time step 11879 (time=53.4555), 0.0615923 s/step
# on time step 11924 (time=53.658), 0.104873 s/step
# on time step 11990 (time=53.955), 0.0785002 s/step
# on time step 12056 (time=54.252), 0.0793748 s/step
# on time step 12113 (time=54.5085), 0.070235 s/step
# on time step 12166 (time=54.747), 0.0943035 s/step
# on time step 12227 (time=55.0215), 0.0658301 s/step
# on time step 12276 (time=55.242), 0.0979844 s/step
# on time step 12342 (time=55.539), 0.0797296 s/step
# on time step 12408 (time=55.836), 0.0783077 s/step
# on time step 12474 (time=56.133), 0.0785677 s/step
# on time step 12537 (time=56.4165), 0.0636369 s/step
# on time step 12584 (time=56.628), 0.0992904 s/step
# on time step 12643 (time=56.8935), 0.0679638 s/step
# on time step 12694 (time=57.123), 0.0943716 s/step
# on time step 12757 (time=57.4065), 0.0635563 s/step
# on time step 12804 (time=57.618), 0.100382 s/step
# on time step 12870 (time=57.915), 0.0790058 s/step
# on time step 12936 (time=58.212), 0.079375 s/step
# on time step 13002 (time=58.509), 0.0790991 s/step
# on time step 13067 (time=58.8015), 0.06171 s/step
# on time step 13112 (time=59.004), 0.122655 s/step
# on time step 13163 (time=59.2335), 0.0784807 s/step
# on time step 13222 (time=59.499), 0.09005 s/step
# on time step 13283 (time=59.7735), 0.0656327 s/step
# on time step 13332 (time=59.994), 0.0967261 s/step
# field decay(t = 60.020999999999994): 8.650263489364445e-05 / 0.15346193400568553 = 0.0005636748647416346
# on time step 13393 (time=60.2685), 0.0656351 s/step
# on time step 13442 (time=60.489), 0.0958037 s/step
# on time step 13508 (time=60.786), 0.0792198 s/step
# on time step 13574 (time=61.083), 0.0789976 s/step
# on time step 13640 (time=61.38), 0.0776076 s/step
# on time step 13706 (time=61.677), 0.0775566 s/step
# on time step 13766 (time=61.947), 0.066919 s/step
# on time step 13816 (time=62.172), 0.0968511 s/step
# on time step 13882 (time=62.469), 0.0782262 s/step
# on time step 13945 (time=62.7525), 0.0637991 s/step
# on time step 13992 (time=62.964), 0.0987803 s/step
# on time step 14058 (time=63.261), 0.079465 s/step
# on time step 14123 (time=63.5535), 0.0617207 s/step
# on time step 14168 (time=63.756), 0.107182 s/step
# on time step 14234 (time=64.053), 0.0790095 s/step
# on time step 14300 (time=64.35), 0.0782415 s/step
# on time step 14365 (time=64.6425), 0.0616357 s/step
# on time step 14410 (time=64.845), 0.105419 s/step
# on time step 14474 (time=65.133), 0.0628734 s/step
# on time step 14520 (time=65.34), 0.103517 s/step
# on time step 14586 (time=65.637), 0.0788461 s/step
# on time step 14644 (time=65.898), 0.0691698 s/step
# on time step 14696 (time=66.132), 0.0930337 s/step
# on time step 14761 (time=66.4245), 0.0616625 s/step
# on time step 14806 (time=66.627), 0.107319 s/step
# on time step 14864 (time=66.888), 0.0690776 s/step
# on time step 14916 (time=67.122), 0.0928669 s/step
# on time step 14982 (time=67.419), 0.0798926 s/step
# on time step 15048 (time=67.716), 0.0792462 s/step
# on time step 15114 (time=68.013), 0.0780574 s/step
# on time step 15180 (time=68.31), 0.0783819 s/step
# on time step 15246 (time=68.607), 0.0776988 s/step
# on time step 15303 (time=68.8635), 0.0705542 s/step
# on time step 15335 (time=69.0075), 0.129365 s/step
# on time step 15393 (time=69.2685), 0.0690998 s/step
# on time step 15444 (time=69.498), 0.0965364 s/step
# on time step 15508 (time=69.786), 0.0628034 s/step
# on time step 15554 (time=69.993), 0.102164 s/step
# field decay(t = 70.02449999999999): 5.397613083545186e-05 / 0.15346193400568553 = 0.0003517232542726337
# on time step 15618 (time=70.281), 0.0626452 s/step
# on time step 15664 (time=70.488), 0.102764 s/step
# on time step 15729 (time=70.7805), 0.0618271 s/step
# on time step 15774 (time=70.983), 0.106458 s/step
# on time step 15840 (time=71.28), 0.0786713 s/step
# on time step 15906 (time=71.577), 0.0789264 s/step
# on time step 15972 (time=71.874), 0.0774519 s/step
# on time step 16038 (time=72.171), 0.0793445 s/step
# on time step 16103 (time=72.4635), 0.0615732 s/step
# on time step 16148 (time=72.666), 0.106391 s/step
# on time step 16212 (time=72.954), 0.0627419 s/step
# on time step 16258 (time=73.161), 0.10402 s/step
# on time step 16324 (time=73.458), 0.078099 s/step
# on time step 16390 (time=73.755), 0.080529 s/step
# on time step 16456 (time=74.052), 0.0771342 s/step
# on time step 16522 (time=74.349), 0.07942 s/step
# on time step 16585 (time=74.6325), 0.0637118 s/step
# on time step 16632 (time=74.844), 0.105315 s/step
# on time step 16698 (time=75.141), 0.0789294 s/step
# on time step 16752 (time=75.384), 0.0743096 s/step
# on time step 16769 (time=75.4605), 0.239402 s/step
# on time step 16808 (time=75.636), 0.130142 s/step
# on time step 16852 (time=75.834), 0.101115 s/step
# on time step 16896 (time=76.032), 0.103601 s/step
# on time step 16940 (time=76.23), 0.110005 s/step
# on time step 16984 (time=76.428), 0.106817 s/step
# on time step 17028 (time=76.626), 0.103582 s/step
# on time step 17072 (time=76.824), 0.104539 s/step
# on time step 17116 (time=77.022), 0.0911136 s/step
# on time step 17160 (time=77.22), 0.0942068 s/step
# on time step 17213 (time=77.4585), 0.0758999 s/step
# on time step 17248 (time=77.616), 0.114362 s/step
# on time step 17292 (time=77.814), 0.111948 s/step
# on time step 17336 (time=78.012), 0.106276 s/step
# on time step 17380 (time=78.21), 0.097246 s/step
# on time step 17424 (time=78.408), 0.0957008 s/step
# on time step 17484 (time=78.678), 0.0667866 s/step
# on time step 17534 (time=78.903), 0.116324 s/step
# on time step 17578 (time=79.101), 0.109601 s/step
# on time step 17622 (time=79.299), 0.0976754 s/step
# on time step 17668 (time=79.506), 0.0870615 s/step
# on time step 17726 (time=79.767), 0.069295 s/step
# on time step 17754 (time=79.893), 0.166312 s/step
# field decay(t = 80.02799999999999): 4.3515845398880084e-05 / 0.15346193400568553 = 0.0002835611689688981
# on time step 17798 (time=80.091), 0.105844 s/step
# on time step 17851 (time=80.3295), 0.0757381 s/step
# on time step 17908 (time=80.586), 0.0933519 s/step
# on time step 17954 (time=80.793), 0.0872026 s/step
# on time step 17996 (time=80.982), 0.097415 s/step
# on time step 18040 (time=81.18), 0.12246 s/step
# on time step 18084 (time=81.378), 0.0978261 s/step
# on time step 18128 (time=81.576), 0.0947748 s/step
# on time step 18172 (time=81.774), 0.0939625 s/step
# on time step 18231 (time=82.0395), 0.0680395 s/step
# on time step 18282 (time=82.269), 0.100547 s/step
# on time step 18346 (time=82.557), 0.0628596 s/step
# on time step 18392 (time=82.764), 0.0998907 s/step
# on time step 18458 (time=83.061), 0.0803567 s/step
# on time step 18520 (time=83.34), 0.064795 s/step
# on time step 18568 (time=83.556), 0.0985717 s/step
# on time step 18612 (time=83.754), 0.0967106 s/step
# on time step 18670 (time=84.015), 0.0692813 s/step
# on time step 18722 (time=84.249), 0.0977098 s/step
# on time step 18766 (time=84.447), 0.0944126 s/step
# on time step 18810 (time=84.645), 0.0979597 s/step
# on time step 18858 (time=84.861), 0.0838614 s/step
# on time step 18898 (time=85.041), 0.107211 s/step
# on time step 18942 (time=85.239), 0.0977448 s/step
# on time step 18986 (time=85.437), 0.113226 s/step
# on time step 19030 (time=85.635), 0.0926765 s/step
# on time step 19074 (time=85.833), 0.0937437 s/step
# on time step 19118 (time=86.031), 0.0959627 s/step
# on time step 19162 (time=86.229), 0.0974498 s/step
# on time step 19206 (time=86.427), 0.113405 s/step
# on time step 19250 (time=86.625), 0.0988369 s/step
# on time step 19294 (time=86.823), 0.0977771 s/step
# on time step 19338 (time=87.021), 0.0955157 s/step
# on time step 19390 (time=87.255), 0.0773707 s/step
# on time step 19446 (time=87.507), 0.0718087 s/step
# on time step 19486 (time=87.687), 0.10003 s/step
# on time step 19536 (time=87.912), 0.0996834 s/step
# on time step 19602 (time=88.209), 0.0787264 s/step
# on time step 19664 (time=88.488), 0.0646314 s/step
# on time step 19705 (time=88.6725), 0.0980308 s/step
# on time step 19739 (time=88.8255), 0.118592 s/step
# on time step 19781 (time=89.0145), 0.0958589 s/step
# on time step 19839 (time=89.2755), 0.0689717 s/step
# on time step 19888 (time=89.496), 0.0964543 s/step
# on time step 19954 (time=89.793), 0.0776636 s/step
# field decay(t = 90.0315): 1.0852684633009004e-05 / 0.15346193400568553 = 7.071906595812176e-05
# run 0 finished at t = 90.0315 (20007 timesteps)

# %%
animate.to_mp4(fps=10, filename="animation.mp4")
# Out:
# Generating MP4...

# %%
box_mx_flux = np.array(mp.get_fluxes(box_mx))
box_px_flux = np.array(mp.get_fluxes(box_px))
box_my_flux = np.array(mp.get_fluxes(box_my))
box_py_flux = np.array(mp.get_fluxes(box_py))
box_mz_flux = np.array(mp.get_fluxes(box_mz))
box_pz_flux = np.array(mp.get_fluxes(box_pz))

total_flux = -box_mx_flux + box_px_flux -box_my_flux+ box_py_flux  -box_mz_flux+ box_pz_flux
crossection = total_flux/incident_intensity



plt.figure()
plt.plot(wls, crossection/ (length**2), "-", color = 'red', label = ("Total crossection"))
plt.xlabel("Wavelength($\mu m$)")
plt.ylabel("$\sigma$_{$\mu m^2$}")
plt.title("Scattering Eficiency")
plt.legend()
plt.savefig("Scattering_spectrum.png")
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_299208/3295812429.py:15: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Wavelength($\mu m$)")
# /tmp/ipykernel_299208/3295812429.py:16: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel("$\sigma$_{$\mu m^2$}")

# %%
L = length

plt.figure()
# plt.plot(wls, crossection/ (L**2), "x", color = 'red', label = ("Total crossection"))
plt.plot(wls, box_mx_flux/ (L**2),  label = ("-x"))
plt.plot(wls, box_px_flux/ (L**2), label = ("+x"))
plt.plot(wls, box_my_flux/ (L**2),  label = ("-y"))
plt.plot(wls, box_py_flux/ (L**2),   label = ("+y"))
plt.plot(wls, box_mz_flux/ (L**2),  label = ("-z"))
plt.plot(wls, box_pz_flux/ (L**2),  label = ("+z"))
plt.xlabel("Wavelength(nm)")
plt.ylabel("Scattering efficiency(arbitrary units)")
plt.legend()
plt.title('Directional Decomposition of Scattered field')
plt.savefig("Scattering_directional_decomposition.png")
plt.show()

# %%
#print("Au valid freq range:", Au.valid_freq_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print("Au valid freq range:", Au.valid_freq_range)
#
# NameError: name 'Au' is not defined

# %%
# sim.plot3D()              # this will draw into the Agg canvas
# plt.savefig("3Dfield.png", dpi=150)

# %%
# import numpy as np
# import scipy.special as sp
# import scipy.interpolate as interp
# import matplotlib.pyplot as plt
# import scipy.optimize as op
# import matplotlib

# matplotlib.rcParams.update({'font.size': 15})

# HBAR = 1.0545718E-34
# ME = 9.10938356E-31
# E0 = 1.60217662E-19
# NE = 5.541318196761572e28
# NE = 5.476415562682574e28

# mu0 = 1.2566370614E-06;
# ep0 = 8.85418781762E-12;
# h = 4.135667516000000e-15;
# c = 3e8;


# def x_Bessel_prime(n, x, j):
#     xj_prime = x * j[:, 1] - n * j[:, 0];
#     return xj_prime;

# def Mie_Solver(Sphere_Radius, Sphere_refractive_index, Wavelengths, RefractiveIndex_Outside = 1, max_iter = 20):
#     c = 3e8;
#     N_m = RefractiveIndex_Outside;  # vacuum
#     Lambda = Wavelengths
#     Freq = c / Lambda;
#     omega = 2 * np.pi * Freq;

#     k = 2 * np.pi * N_m / Lambda;
#     x = Sphere_Radius * k;

#     if hasattr(Sphere_refractive_index, "__len__"):
#         N_s = Sphere_refractive_index
#     else:
#         N_s = Wavelengths / Wavelengths * Sphere_refractive_index

#     N = N_s / N_m;

#     j_mx = np.zeros([len(omega), 3], dtype='complex128');
#     j_x = np.zeros([len(omega), 3], dtype='complex128');
#     y_x = np.zeros([len(omega), 3], dtype='complex128');
#     xjx_prime = np.zeros([len(omega), 3], dtype='complex128');
#     NxjNx_prime = np.zeros([len(omega), 3], dtype='complex128');
#     h_x = np.zeros([len(omega), 3], dtype='complex128');
#     xhx_prime = np.zeros([len(omega), 3], dtype='complex128');

#     I = 1j

#     i = 0;
#     j_x[:, 0] = sp.jn(i + 0.5, x) * np.sqrt(np.pi / (2 * x))
#     j_mx[:, 0] = sp.jn(i + 0.5, N * x) * np.sqrt(np.pi / (2 * N * x))
#     y_x[:, 0] = sp.yv(i + 0.5, x) * np.sqrt(np.pi / (2 * x))
#     h_x[:, 0] = j_x[:, 0] + I * y_x[:, 0];

#     Q_sca = 0;
#     Q_ext = 0;

#     A_n_track = []
#     B_n_track = []

#     for i in range(1, max_iter + 1):
#         # print(i)

#         j_x[:, 2] = j_x[:, 1];
#         j_x[:, 1] = j_x[:, 0];

#         j_mx[:, 2] = j_mx[:, 1];
#         j_mx[:, 1] = j_mx[:, 0];

#         y_x[:, 2] = y_x[:, 1];
#         y_x[:, 1] = y_x[:, 0];

#         j_x[:, 0] = sp.jv(i + 0.5, x) * np.sqrt(np.pi / (2 * x))
#         j_mx[:, 0] = sp.jv(i + 0.5, N * x) * np.sqrt(np.pi / (2 * N * x))
#         y_x[:, 0] = sp.yv(i + 0.5, x) * np.sqrt(np.pi / (2 * x))

#         h_x[:, 2] = h_x[:, 1];
#         h_x[:, 1] = h_x[:, 0];
#         h_x[:, 0] = j_x[:, 0] + I * y_x[:, 0];

#         xjx_prime[:, 0] = x_Bessel_prime(i, x, j_x);
#         NxjNx_prime[:, 0] = x_Bessel_prime(i, N * x, j_mx);
#         xhx_prime[:, 0] = x_Bessel_prime(i, x, h_x);

#         A_n = N * N * j_mx[:, 0] * xjx_prime[:, 0] - j_x[:, 0] * NxjNx_prime[:, 0];
#         A_n = - A_n / (N * N * j_mx[:, 0] * xhx_prime[:, 0] - h_x[:, 0] * NxjNx_prime[:, 0]);

#         B_n = j_mx[:, 0] * xjx_prime[:, 0] - j_x[:, 0] * NxjNx_prime[:, 0];
#         B_n = - B_n / (j_mx[:, 0] * xhx_prime[:, 0] - h_x[:, 0] * NxjNx_prime[:, 0]);

#         A_n_track.append(A_n)
#         B_n_track.append(B_n)

#         Q_sca = Q_sca + (2 * i + 1) * (np.abs(A_n) * np.abs(A_n) + np.abs(B_n) * np.abs(B_n));
#         Q_ext = Q_ext + (2 * i + 1) * (np.real(A_n + B_n));

#     Q_sca = Q_sca * 2 / (x * x);
#     Q_ext = -Q_ext * 2 / (x * x);
#     Q_abs = Q_ext - Q_sca;

#     return Q_sca, Q_abs, Q_ext
